# %%
import cv2
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %%
#Reading the image
img = cv2.imread('Data/Lab/07-08-2019-14.02-.jpg')

# %%
#convert to RGB
imgRGB_original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
#Showing the output
plt.imshow(imgRGB_original)
plt.grid()

# %%
#Visualising the major portion
img_cropped = imgRGB_original[1000:2000,0:2000]
plt.imshow(img_cropped)

# %%
#Core portion extraction- Colour black
plt.imshow(img_cropped[835:985,1000:1150])

# %%
#Finding the average colour values of the core portion 
R1 = img_cropped[835:985,1000:1150,0].mean()
G1 = img_cropped[835:985,1000:1150,1].mean()
B1 = img_cropped[835:985,1000:1150,2].mean()

# %%
"""after having the mean values, identify the difference with original values 
from the colour card which is (52,52,52) for the colour black"""
# Out:
# 'after having the mean values, identify the difference with original values \nfrom the colour card which is (52,52,52) for the colour black'

# %%
#Loop to apply the colour values changes to entire image
arr = np.array(img_cropped)
# grab the image dimensions
h1 = arr.shape[0]
w1 = arr.shape[1]  
# loop over the image, pixel by pixel
for y in range(0, h1):
    for x in range(0, w1):
        arr[y, x,0] = arr[y, x,0]+ (52- R1)  # add or substract the difference of Red
        arr[y, x,1] = arr[y, x,1]+ (52-G1) # add or substract the difference of green
        arr[y, x,2] = arr[y, x,2]+(52-B1) # add or substract the difference of Blue

# %%
#Print the colour corrected image
plt.imshow(arr)

# %%
#Saving back the normalised image
#output_filename = filename + '_Normalised.jpg'
plt.imsave('normalisedImage.jpg' ,arr)

# %%
"""Executable Code"""
# Out:
# 'Executable Code'

# %%
import cv2
import os
import sys
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

path = "Data/Lab/*.jpg"

for file in glob.glob(path):
    filename = file.split('/')[2].split('.j')[0]
    img = cv2.imread(file)
    imgRGB_original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    img_cropped = imgRGB_original[1000:2000,0:2000]
    #Finding the average colour values of the core portion 
    R1 = img_cropped[835:985,1000:1150,0].mean()
    G1 = img_cropped[835:985,1000:1150,1].mean()
    B1 = img_cropped[835:985,1000:1150,2].mean()
    
    #Adjusting the colours in the image
    arr = np.array(img_cropped)
    # grab the image dimensions
    h1 = arr.shape[0]
    w1 = arr.shape[1]  
    # loop over the image, pixel by pixel
    for y in range(0, h1):
        for x in range(0, w1):
            arr[y, x,0] = arr[y, x,0]+ (52- R1)  # add or substract the difference of Red
            arr[y, x,1] = arr[y, x,1]+ (52-G1) # add or substract the difference of green
            arr[y, x,2] = arr[y, x,2]+(52-B1) # add or substract the difference of Blue
     
    #Saving the Normalised Images
    output_filename = filename + '_normalised.jpg'
    plt.imsave('Data/Lab/Normalised/'+output_filename ,arr)
